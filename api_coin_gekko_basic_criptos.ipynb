# %%
# !pip install pycoingecko pandas python-dotenv
# Out:
# Requirement already satisfied: pycoingecko in ./.conda/lib/python3.11/site-packages (3.2.0)
# Requirement already satisfied: pandas in ./.conda/lib/python3.11/site-packages (2.2.3)
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: requests in ./.conda/lib/python3.11/site-packages (from pycoingecko) (2.32.3)
# Requirement already satisfied: numpy>=1.23.2 in ./.conda/lib/python3.11/site-packages (from pandas) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.conda/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.conda/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.conda/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in ./.conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.conda/lib/python3.11/site-packages (from requests->pycoingecko) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.conda/lib/python3.11/site-packages (from requests->pycoingecko) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.conda/lib/python3.11/site-packages (from requests->pycoingecko) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.conda/lib/python3.11/site-packages (from requests->pycoingecko) (2025.4.26)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.1.0

# %%
import requests
import pandas as pd
import time
from dotenv import load_dotenv
import os

API_KEY = os.getenv("COINGECKO_API_KEY")

# %%
def obtener_monedas_categoria_pro(cat_id, nombre, num_registros=3000, por_pagina=250, sleep_time=1):
    """
    Descarga monedas de una categoría específica desde CoinGecko PRO usando API Key.
    """
    url = "https://api.coingecko.com/api/v3/coins/markets"  # Cambiado a la URL pública
    headers = {
        "x-cg-demo-api-key": API_KEY  # Si tu clave es demo, usa este header
    }
    num_paginas = (num_registros // por_pagina) + 1
    dfs_cat = []
    for page in range(1, num_paginas + 1):
        params = {
            "vs_currency": "usd",
            "category": cat_id,
            "per_page": por_pagina,
            "page": page
        }
        try:
            print(f"Obteniendo página {page} de {nombre}")
            resp = requests.get(url, headers=headers, params=params)
            if resp.status_code == 429:
                print("Rate limit alcanzado. Esperando 60 segundos...")
                time.sleep(60)
                continue
            resp.raise_for_status()
            monedas = resp.json()
            if not monedas:
                break
            df = pd.DataFrame(monedas)
            df['categoria'] = nombre
            dfs_cat.append(df)
            if len(df) < por_pagina:
                break
            time.sleep(sleep_time)
        except Exception as e:
            print(f"Error: {e}. Esperando 60 segundos antes de reintentar...")
            time.sleep(60)
            continue
    if dfs_cat:
        df_cat = pd.concat(dfs_cat, ignore_index=True)
        return df_cat.head(num_registros)
    else:
        return pd.DataFrame()

# %%
def obtener_todas_las_categorias_pro(categorias, num_registros=3000, por_pagina=250, sleep_time=1):
    """
    Descarga monedas de todas las categorías especificadas usando CoinGecko PRO.
    """
    lista_dfs = []
    for cat_id, nombre in categorias.items():
        df_cat = obtener_monedas_categoria_pro(
            cat_id, nombre, num_registros=num_registros, por_pagina=por_pagina, sleep_time=sleep_time
        )
        if not df_cat.empty:
            lista_dfs.append(df_cat)
    if lista_dfs:
        df_final = pd.concat(lista_dfs, ignore_index=True)
        return df_final.head(num_registros)
    else:
        return pd.DataFrame()

# %%
categorias = {
    'artificial-intelligence': 'AI',
    'gaming': 'Gaming',
    'meme-token': 'Memes',
    'real-world-assets-rwa': 'RWA'
}

# Descargar datos
df_final = obtener_todas_las_categorias_pro(categorias, num_registros=3000, por_pagina=250, sleep_time=1)

# Guardar resultado
df_final.to_csv("./data/category_cryptos_small.csv", index=False)
df_final.head()
# Out:
# Obteniendo página 1 de AI
# Obteniendo página 2 de AI
# Obteniendo página 3 de AI
# Obteniendo página 1 de Gaming
# Obteniendo página 2 de Gaming
# Obteniendo página 3 de Gaming
# Obteniendo página 4 de Gaming
# /tmp/ipykernel_56112/2807034364.py:40: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_cat = pd.concat(dfs_cat, ignore_index=True)
# Obteniendo página 1 de Memes
# Obteniendo página 2 de Memes
# Obteniendo página 3 de Memes
# Obteniendo página 4 de Memes
# Obteniendo página 5 de Memes
# Obteniendo página 6 de Memes
# Obteniendo página 7 de Memes
# Obteniendo página 8 de Memes
# Obteniendo página 9 de Memes
# Obteniendo página 10 de Memes
# Obteniendo página 11 de Memes
# Obteniendo página 12 de Memes
# Obteniendo página 13 de Memes
# Obteniendo página 1 de RWA
# Obteniendo página 2 de RWA
# /tmp/ipykernel_56112/2807034364.py:40: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_cat = pd.concat(dfs_cat, ignore_index=True)
#                   id  symbol                                   name  \
# 0          bittensor     tao                              Bittensor
# 1               near    near                          NEAR Protocol
# 2  internet-computer     icp                      Internet Computer
# 3       render-token  render                                 Render
# 4           fetch-ai     fet  Artificial Superintelligence Alliance
#
#                                                image  current_price  \
# 0  https://coin-images.coingecko.com/coins/images...     344.130000
# 1  https://coin-images.coingecko.com/coins/images...       2.320000
# 2  https://coin-images.coingecko.com/coins/images...       4.580000
# 3  https://coin-images.coingecko.com/coins/images...       4.340000
# 4  https://coin-images.coingecko.com/coins/images...       0.651341
#
#      market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0  2.994709e+09             42.0             7.227953e+09    68017743.0
# 1  2.809549e+09             44.0             2.898757e+09   117948852.0
# 2  2.441800e+09             49.0             2.441800e+09    44814619.0
# 3  2.248037e+09             54.0             2.312129e+09   177921980.0
# 4  1.696797e+09             65.0             1.768145e+09    92159387.0
#
#      high_24h  ...    max_supply     ath  ath_change_percentage  \
# 0  357.080000  ...  2.100000e+07  757.60              -54.63478
# 1    2.450000  ...           NaN   20.44              -88.63663
# 2    4.760000  ...           NaN  700.65              -99.34586
# 3    4.630000  ...           NaN   13.53              -67.95649
# 4    0.693173  ...  2.714494e+09    3.45              -81.09757
#
#                    ath_date        atl  atl_change_percentage  \
# 0  2024-03-07T18:45:36.466Z  30.830000             1014.78911
# 1  2022-01-16T22:09:45.873Z   0.526762              340.89303
# 2  2021-05-10T16:05:53.653Z   2.870000               59.97170
# 3  2024-03-17T16:30:24.636Z   0.036657            11731.37655
# 4  2024-03-28T17:21:18.050Z   0.008170             7892.05190
#
#                    atl_date  \
# 0  2023-05-14T08:57:53.732Z
# 1  2020-11-04T16:09:15.137Z
# 2  2023-09-22T00:29:57.369Z
# 3  2020-06-16T13:22:25.900Z
# 4  2020-03-13T02:24:18.347Z
#
#                                                  roi  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4  {'times': 6.512585943497473, 'currency': 'usd'...
#
#                last_updated  categoria
# 0  2025-05-04T22:32:53.917Z         AI
# 1  2025-05-04T22:32:54.221Z         AI
# 2  2025-05-04T22:32:52.200Z         AI
# 3  2025-05-04T22:32:52.853Z         AI
# 4  2025-05-04T22:32:46.467Z         AI
#
# [5 rows x 27 columns]

# %%
import requests


resp = requests.get(url, headers=headers)
print(resp.json())
# Out:
# {'error': 'Missing parameter vs_currency'}
